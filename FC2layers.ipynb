# %%
# !python main2.py -elu_alpha 0.01 -dropout_p 0.05 -expname 'fc2_alpha0.01_drop0.05_lr0.004_epoch300_batch64' -lr 0.004 -batch_size 64 -num_epochs 300
# Out:
# cuda
# (1080, 1, 2, 750) (1080,) (1080, 1, 2, 750) (1080,)
# 100%|███████████████████████████████████████████| 17/17 [00:00<00:00, 98.14it/s]
# Epoch: 1
# Loss: 0.009345867070886823
# Training Acc. (%): 66.39%
# Test Acc. (%): 63.98%
# 100%|██████████████████████████████████████████| 17/17 [00:00<00:00, 115.15it/s]
# Epoch: 2
# Loss: 0.008074260475458922
# Training Acc. (%): 74.44%
# Test Acc. (%): 70.46%
# 100%|██████████████████████████████████████████| 17/17 [00:00<00:00, 114.55it/s]
# Epoch: 3
# Loss: 0.007611155923869874
# Training Acc. (%): 76.85%
# Test Acc. (%): 72.69%
# 100%|██████████████████████████████████████████| 17/17 [00:00<00:00, 115.79it/s]
# Epoch: 4
# Loss: 0.006935515392709661
# Training Acc. (%): 79.07%
# Test Acc. (%): 74.26%
# 100%|██████████████████████████████████████████| 17/17 [00:00<00:00, 116.10it/s]
# Epoch: 5
# Loss: 0.006789265186698349
# Training Acc. (%): 80.19%
# Test Acc. (%): 75.74%
# ...

# %%
# !python main2.py -elu_alpha 0.01 -dropout_p 0.05 -expname 'fc2_alpha0.01_drop0.05_lr0.004_batch32_epoch300' -lr 0.004 -batch_size 32 -num_epochs 300
# !python main2.py -elu_alpha 0.01 -dropout_p 0.05 -expname 'fc2_alpha0.01_drop0.05_lr0.004_batch64_epoch300' -lr 0.004 -batch_size 64 -num_epochs 300
# !python main2.py -elu_alpha 0.01 -dropout_p 0.05 -expname 'fc2_alpha0.01_drop0.05_lr0.004_batch128_epoch300' -lr 0.004 -batch_size 128 -num_epochs 300
# !python main2.py -elu_alpha 0.01 -dropout_p 0.05 -expname 'fc2_alpha0.01_drop0.05_lr0.004_batch256_epoch300' -lr 0.004 -batch_size 256 -num_epochs 300
# !python main2.py -elu_alpha 0.01 -dropout_p 0.05 -expname 'fc2_alpha0.01_drop0.05_lr0.006_batch32_epoch300' -lr 0.006 -batch_size 32 -num_epochs 300
# !python main2.py -elu_alpha 0.01 -dropout_p 0.05 -expname 'fc2_alpha0.01_drop0.05_lr0.006_batch64_epoch300' -lr 0.006 -batch_size 64 -num_epochs 300
# !python main2.py -elu_alpha 0.01 -dropout_p 0.05 -expname 'fc2_alpha0.01_drop0.05_lr0.006_batch128_epoch300' -lr 0.006 -batch_size 128 -num_epochs 300
# !python main2.py -elu_alpha 0.01 -dropout_p 0.05 -expname 'fc2_alpha0.01_drop0.05_lr0.006_batch256_epoch300' -lr 0.006 -batch_size 256 -num_epochs 300
# Out:
# cuda
# (1080, 1, 2, 750) (1080,) (1080, 1, 2, 750) (1080,)
# 100%|██████████████████████████████████████████| 34/34 [00:00<00:00, 154.61it/s]
# Epoch: 1
# Loss: 0.018974170861420808
# Training Acc. (%): 64.91%
# Test Acc. (%): 70.56%
# 100%|██████████████████████████████████████████| 34/34 [00:00<00:00, 164.96it/s]
# Epoch: 2
# Loss: 0.016411762601799437
# Training Acc. (%): 74.26%
# Test Acc. (%): 72.13%
# 100%|██████████████████████████████████████████| 34/34 [00:00<00:00, 177.40it/s]
# Epoch: 3
# Loss: 0.01510116786316589
# Training Acc. (%): 75.65%
# Test Acc. (%): 72.50%
# 100%|██████████████████████████████████████████| 34/34 [00:00<00:00, 176.66it/s]
# Epoch: 4
# Loss: 0.014324998165722247
# Training Acc. (%): 78.43%
# Test Acc. (%): 72.87%
# 100%|██████████████████████████████████████████| 34/34 [00:00<00:00, 175.22it/s]
# Epoch: 5
# Loss: 0.014362606433806597
# Training Acc. (%): 76.48%
# Test Acc. (%): 73.89%
# ...

# %%
import pickle
import glob
import pickle
import matplotlib as plt
import numpy as np
import pandas as pd

files = glob.glob('results/fc2_*')

# %%
train_aac_list = {}
train_loss_list = {}
test_aac_list = {}

for file in files:
    try:
        # Load the pickled list from a file
        with open(file, 'rb') as f:
            x = list(pickle.load(f))

        train_aac_list[file] = x[0]
        train_loss_list[file] = x[1]
        test_aac_list[file] = x[2]
    except:
        print(file)

# %%
best = 0
for file, test_aac in test_aac_list.items():
    try:
        alpha = "0."+str(file.split('_')[1].split('.')[1])
        drop_rate = "0."+str(file.split('_')[2].split('.')[1])
        best_test_aac = max(test_aac)
        epoch = test_aac.index(best_test_aac)+1
        if best_test_aac<best:
            pass
        else:
            best = best_test_aac
            print(file)
            print(f'alpha is {alpha}')
            print(f'drop_rate is {drop_rate}')
            print(f'epoch is {epoch}')
            print(f'best_test_aac is {best_test_aac}')
            print('=================================================')
    except:
        pass
# Out:
# results/fc2_alpha0.01_drop0.05_lr0.004_batch32_epoch300_lists.pkl
# alpha is 0.01
# drop_rate is 0.05
# epoch is 207
# best_test_aac is 84.9074074074074
# ...
# results/fc2_alpha0.01_drop0.05_lr0.004_epoch300_batch64_lists.pkl
# alpha is 0.01
# drop_rate is 0.05
# epoch is 241
# best_test_aac is 87.12962962962963
# ...
# results/fc2_alpha0.01_drop0.05_lr0.006_batch128_epoch300_lists.pkl
# alpha is 0.01
# drop_rate is 0.05
# epoch is 233
# best_test_aac is 87.31481481481481
# ...
# results/fc2_alpha0.01_drop0.05_lr0.004_batch64_epoch300_lists.pkl
# alpha is 0.01
# drop_rate is 0.05
# epoch is 270
# best_test_aac is 88.42592592592592
# ...
